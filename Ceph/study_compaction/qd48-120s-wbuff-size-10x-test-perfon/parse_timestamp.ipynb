# %%
import sys
import numpy as np
from pandas import read_csv
import pandas as pd
from dateutil import parser
import datetime
import matplotlib.pyplot as plt
f1='dump_time_stamps_vec.csv'
data1=read_csv(f1, skiprows=10, parse_dates=True, squeeze=True, sep=',', header=None)
datalen = len(data1.values)

def check_bracket(str):
    if str == None:
        return "0"
    if str.startswith('['):
        return str[1:]
    if str.endswith(']'):
        return str[:-1]
    return str

# for bluestore latency
x_bs_lat = []
y_bs_lat = []


# process the time stamps
for i in range(datalen-1):
    # simple writes
    #if len(data1.values[i,:]) == len(data1.values[i+1,:]) and data1.values[i,2] == 'simple_s':
    if data1.values[i,2] == 'simple_s':
        # for first ctx
        ctr_ctx1 = parser.parse(check_bracket(data1.values[i,1]))
        simple_s1 = parser.parse(check_bracket(data1.values[i,3]))
        aio_done1 = parser.parse(check_bracket(data1.values[i,5]))
        flush_cmt_s1 = parser.parse(check_bracket(data1.values[i,7]))
        flush_cmt_e1 = parser.parse(check_bracket(data1.values[i,9]))
        simple_e1 = parser.parse(check_bracket(data1.values[i,11]))
        # for second ctx
        '''ctr_ctx2 = parser.parse(check_bracket(data1.values[i+1,1]))
        simple_s2 = parser.parse(check_bracket(data1.values[i+1,3]))
        aio_done2 = parser.parse(check_bracket(data1.values[i+1,5]))
        flush_cmt_s2 = parser.parse(check_bracket(data1.values[i+1,7]))
        flush_cmt_e2 = parser.parse(check_bracket(data1.values[i+1,9]))
        simple_e2 = parser.parse(check_bracket(data1.values[i+1,11]))'''
        # sanity check of timestamps
        if simple_s1 < ctr_ctx1 or aio_done1 < simple_s1 or flush_cmt_s1 < aio_done1 or flush_cmt_e1 < flush_cmt_s1 or simple_e1 < flush_cmt_e1:
            print("simple writes timestamp order is incorrect")
        # bluestore latency
        bluestore_lat_simple = simple_e1 - simple_s1
        x_bs_lat.append(simple_s1)
        y_bs_lat.append(bluestore_lat_simple.total_seconds())
        
        # spikes
        if bluestore_lat_simple.total_seconds() > 0.05:
            print("bluestore_lat_simple",bluestore_lat_simple.total_seconds(),", simple_start",check_bracket(data1.values[i,3]))

    # deferred writes
    elif data1.values[i,2] == 'deferred_s':
        ctr_ctx1 = parser.parse(check_bracket(data1.values[i,1]))
        deferred_s1 = parser.parse(check_bracket(data1.values[i,3]))
        flush_cmt_s1 = parser.parse(check_bracket(data1.values[i,5]))
        flush_cmt_e1 = parser.parse(check_bracket(data1.values[i,7]))
        deferred_e1 = parser.parse(check_bracket(data1.values[i,9]))
        # sanity check of timestamps
        if deferred_s1 < ctr_ctx1 or flush_cmt_s1 < deferred_s1 or flush_cmt_e1 < flush_cmt_s1 or deferred_e1 < flush_cmt_e1:
            print("deferred writes timestamp order is incorrect")
        # bluestore latency
        bluestore_lat_deferred = deferred_e1 - deferred_s1
        x_bs_lat.append(deferred_s1)
        y_bs_lat.append(bluestore_lat_deferred.total_seconds())
        
        # spikes
        if bluestore_lat_deferred.total_seconds() > 0.05:
            print("bluestore_lat_deferred",bluestore_lat_deferred.total_seconds(),", deferred_start",check_bracket(data1.values[i,3]))

# plot           
fig, ax = plt.subplots()
#ax.set_xscale('log')
ax.plot(x_bs_lat, y_bs_lat, label='4096 KiB')
ax.set(xlabel='time stamps', ylabel='latency [secs]', title='BlueStore Latency Time Series')
#plt.legend()
plt.show()
plt.close()
# Out:
# bluestore_lat_simple 0.08428 , simple_start 2020-05-12T09:54:40.757023-0500
# bluestore_lat_simple 0.123164 , simple_start 2020-05-12T09:55:11.201221-0500
# bluestore_lat_simple 0.123246 , simple_start 2020-05-12T09:55:11.201271-0500
# bluestore_lat_simple 0.123225 , simple_start 2020-05-12T09:55:11.201303-0500
# bluestore_lat_simple 0.12323 , simple_start 2020-05-12T09:55:11.201311-0500
# bluestore_lat_simple 0.123169 , simple_start 2020-05-12T09:55:11.201382-0500
# bluestore_lat_simple 0.123175 , simple_start 2020-05-12T09:55:11.201384-0500
# bluestore_lat_simple 0.123142 , simple_start 2020-05-12T09:55:11.201428-0500
# bluestore_lat_simple 0.123146 , simple_start 2020-05-12T09:55:11.201428-0500
# bluestore_lat_simple 0.123146 , simple_start 2020-05-12T09:55:11.201438-0500
# bluestore_lat_simple 0.123076 , simple_start 2020-05-12T09:55:11.201511-0500
# bluestore_lat_simple 0.12304 , simple_start 2020-05-12T09:55:11.201557-0500
# bluestore_lat_simple 0.122953 , simple_start 2020-05-12T09:55:11.201656-0500
# bluestore_lat_simple 0.122887 , simple_start 2020-05-12T09:55:11.201730-0500
# bluestore_lat_simple 0.122885 , simple_start 2020-05-12T09:55:11.201736-0500
# bluestore_lat_simple 0.122365 , simple_start 2020-05-12T09:55:11.202264-0500
# bluestore_lat_simple 0.122358 , simple_start 2020-05-12T09:55:11.202280-0500
# bluestore_lat_simple 0.122313 , simple_start 2020-05-12T09:55:11.202328-0500
# bluestore_lat_simple 0.122303 , simple_start 2020-05-12T09:55:11.202344-0500
# bluestore_lat_simple 0.122282 , simple_start 2020-05-12T09:55:11.202376-0500
# bluestore_lat_simple 0.122277 , simple_start 2020-05-12T09:55:11.202384-0500
# bluestore_lat_simple 0.122281 , simple_start 2020-05-12T09:55:11.202387-0500
# bluestore_lat_simple 0.122315 , simple_start 2020-05-12T09:55:11.202421-0500
# bluestore_lat_simple 0.122283 , simple_start 2020-05-12T09:55:11.202464-0500
# bluestore_lat_simple 0.122276 , simple_start 2020-05-12T09:55:11.202479-0500
# bluestore_lat_simple 0.122231 , simple_start 2020-05-12T09:55:11.202532-0500
# bluestore_lat_simple 0.122224 , simple_start 2020-05-12T09:55:11.202548-0500
# bluestore_lat_simple 0.122222 , simple_start 2020-05-12T09:55:11.202565-0500
# bluestore_lat_simple 0.122224 , simple_start 2020-05-12T09:55:11.202571-0500
# bluestore_lat_simple 0.122214 , simple_start 2020-05-12T09:55:11.202589-0500
# bluestore_lat_simple 0.122186 , simple_start 2020-05-12T09:55:11.202623-0500
# bluestore_lat_simple 0.122074 , simple_start 2020-05-12T09:55:11.202744-0500
# bluestore_lat_simple 0.122027 , simple_start 2020-05-12T09:55:11.202801-0500
# bluestore_lat_simple 0.121576 , simple_start 2020-05-12T09:55:11.204172-0500
# bluestore_lat_simple 0.124028 , simple_start 2020-05-12T09:55:40.781568-0500
# bluestore_lat_simple 0.124005 , simple_start 2020-05-12T09:55:40.781602-0500
# bluestore_lat_simple 0.123913 , simple_start 2020-05-12T09:55:40.781700-0500
# bluestore_lat_simple 0.123399 , simple_start 2020-05-12T09:55:40.782224-0500
# bluestore_lat_simple 0.123275 , simple_start 2020-05-12T09:55:40.782354-0500
# bluestore_lat_simple 0.123128 , simple_start 2020-05-12T09:55:40.782508-0500
# bluestore_lat_simple 0.123022 , simple_start 2020-05-12T09:55:40.782626-0500
# bluestore_lat_simple 0.123032 , simple_start 2020-05-12T09:55:40.782654-0500
# bluestore_lat_simple 0.123025 , simple_start 2020-05-12T09:55:40.782679-0500
# bluestore_lat_simple 0.123014 , simple_start 2020-05-12T09:55:40.782695-0500
# bluestore_lat_simple 0.12297 , simple_start 2020-05-12T09:55:40.782752-0500
# bluestore_lat_simple 0.122972 , simple_start 2020-05-12T09:55:40.782761-0500
# bluestore_lat_simple 0.123026 , simple_start 2020-05-12T09:55:40.782803-0500
# bluestore_lat_simple 0.12301 , simple_start 2020-05-12T09:55:40.782829-0500
# bluestore_lat_simple 0.123015 , simple_start 2020-05-12T09:55:40.782835-0500
# bluestore_lat_simple 0.12301 , simple_start 2020-05-12T09:55:40.782850-0500
# bluestore_lat_simple 0.122947 , simple_start 2020-05-12T09:55:40.782922-0500
# bluestore_lat_simple 0.123052 , simple_start 2020-05-12T09:55:40.782919-0500
# bluestore_lat_simple 0.123036 , simple_start 2020-05-12T09:55:40.782972-0500
# bluestore_lat_simple 0.123011 , simple_start 2020-05-12T09:55:40.783011-0500
# bluestore_lat_simple 0.123022 , simple_start 2020-05-12T09:55:40.783012-0500
# bluestore_lat_simple 0.123021 , simple_start 2020-05-12T09:55:40.783027-0500
# bluestore_lat_simple 0.123033 , simple_start 2020-05-12T09:55:40.783027-0500
# bluestore_lat_simple 0.122773 , simple_start 2020-05-12T09:55:40.783307-0500
# bluestore_lat_simple 0.123007 , simple_start 2020-05-12T09:55:40.783087-0500
# bluestore_lat_simple 0.122779 , simple_start 2020-05-12T09:55:40.783334-0500
# bluestore_lat_simple 0.123416 , simple_start 2020-05-12T09:56:11.379068-0500
# bluestore_lat_simple 0.123386 , simple_start 2020-05-12T09:56:11.379115-0500
# bluestore_lat_simple 0.123376 , simple_start 2020-05-12T09:56:11.379138-0500
# bluestore_lat_simple 0.123256 , simple_start 2020-05-12T09:56:11.379269-0500
# bluestore_lat_simple 0.122468 , simple_start 2020-05-12T09:56:11.380111-0500
# bluestore_lat_simple 0.122435 , simple_start 2020-05-12T09:56:11.380151-0500
# bluestore_lat_simple 0.122451 , simple_start 2020-05-12T09:56:11.380147-0500
# bluestore_lat_simple 0.12246 , simple_start 2020-05-12T09:56:11.380170-0500
# bluestore_lat_simple 0.122457 , simple_start 2020-05-12T09:56:11.380179-0500
# bluestore_lat_simple 0.122429 , simple_start 2020-05-12T09:56:11.380220-0500
# bluestore_lat_simple 0.122426 , simple_start 2020-05-12T09:56:11.380234-0500
# bluestore_lat_simple 0.12242 , simple_start 2020-05-12T09:56:11.380258-0500
# bluestore_lat_simple 0.122404 , simple_start 2020-05-12T09:56:11.380285-0500
# bluestore_lat_simple 0.122416 , simple_start 2020-05-12T09:56:11.380286-0500
# bluestore_lat_simple 0.122382 , simple_start 2020-05-12T09:56:11.380327-0500
# bluestore_lat_simple 0.122345 , simple_start 2020-05-12T09:56:11.380376-0500
# bluestore_lat_simple 0.122352 , simple_start 2020-05-12T09:56:11.380380-0500
# bluestore_lat_simple 0.12233 , simple_start 2020-05-12T09:56:11.380415-0500
# bluestore_lat_simple 0.122341 , simple_start 2020-05-12T09:56:11.380439-0500
# bluestore_lat_simple 0.122354 , simple_start 2020-05-12T09:56:11.380440-0500
# bluestore_lat_simple 0.122314 , simple_start 2020-05-12T09:56:11.380493-0500
# bluestore_lat_simple 0.122325 , simple_start 2020-05-12T09:56:11.380494-0500
# bluestore_lat_simple 0.122512 , simple_start 2020-05-12T09:56:11.382705-0500
# bluestore_lat_simple 0.122479 , simple_start 2020-05-12T09:56:11.382753-0500
# bluestore_lat_simple 0.122536 , simple_start 2020-05-12T09:56:11.382752-0500
# bluestore_lat_simple 0.122496 , simple_start 2020-05-12T09:56:11.382802-0500
# bluestore_lat_simple 0.122465 , simple_start 2020-05-12T09:56:11.382843-0500
# bluestore_lat_simple 0.122477 , simple_start 2020-05-12T09:56:11.382843-0500
# bluestore_lat_simple 0.122469 , simple_start 2020-05-12T09:56:11.382861-0500
# bluestore_lat_simple 0.122465 , simple_start 2020-05-12T09:56:11.382871-0500
# bluestore_lat_simple 0.122487 , simple_start 2020-05-12T09:56:11.382880-0500
# bluestore_lat_simple 0.122463 , simple_start 2020-05-12T09:56:11.382916-0500
# bluestore_lat_simple 0.122472 , simple_start 2020-05-12T09:56:11.382916-0500
# bluestore_lat_simple 0.122448 , simple_start 2020-05-12T09:56:11.382950-0500
# bluestore_lat_simple 0.122426 , simple_start 2020-05-12T09:56:11.382982-0500
# bluestore_lat_simple 0.122407 , simple_start 2020-05-12T09:56:11.383011-0500
# bluestore_lat_simple 0.122394 , simple_start 2020-05-12T09:56:11.383070-0500
# bluestore_lat_simple 0.122389 , simple_start 2020-05-12T09:56:11.383085-0500
# bluestore_lat_simple 0.122384 , simple_start 2020-05-12T09:56:11.383095-0500
# bluestore_lat_simple 0.122277 , simple_start 2020-05-12T09:56:11.383211-0500
# bluestore_lat_simple 0.121364 , simple_start 2020-05-12T09:56:11.384129-0500
# bluestore_lat_simple 0.121058 , simple_start 2020-05-12T09:56:11.384443-0500
# bluestore_lat_simple 0.120911 , simple_start 2020-05-12T09:56:11.384595-0500
# bluestore_lat_simple 0.106743 , simple_start 2020-05-12T09:56:11.398771-0500
# bluestore_lat_simple 0.102626 , simple_start 2020-05-12T09:56:11.402898-0500
# bluestore_lat_simple 0.102322 , simple_start 2020-05-12T09:56:11.403212-0500
# bluestore_lat_simple 0.102139 , simple_start 2020-05-12T09:56:11.403400-0500
# bluestore_lat_simple 0.10191 , simple_start 2020-05-12T09:56:11.403638-0500
